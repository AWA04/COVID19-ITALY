# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv('covid-age (1).csv')

# %%
data.head()
# Out:
#    Unnamed: 0 age_classes  male_cases  male_deaths  female_cases  \
# 0           0         0-9         381            0           307
# 1           1       10-19         475            0           454
# 2           2       20-29        1919            4          2531
# 3           3       30-39        3505           22          3885
# 4           4       40-49        6480           81          7130
#
#    female_deaths  total_cases  total_deaths  piemonte_cases  lombardia_cases  \
# 0              0          693             0              35              205
# 1              0          931             0              29              170
# 2              2         4530             6             311             1494
# 3              7         7466            29             479             2778
# 4             29        13701           110            1021             5436
#
#    ...  toscana_cases  umbria_cases  marche_cases  lazio_cases  abruzzo_cases  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'age_classes', 'male_cases', 'male_deaths',
#        'female_cases', 'female_deaths', 'total_cases', 'total_deaths',
#        'piemonte_cases', 'lombardia_cases', 'veneto_cases',
#        'emilia-romagna_cases', 'valleaosta_cases', 'trento_cases',
#        'friuli-veneziagiulia_cases', 'liguria_cases', 'toscana_cases',
#        'umbria_cases', 'marche_cases', 'lazio_cases', 'abruzzo_cases',
#        'molise_cases', 'campania_cases', 'puglia_cases', 'sicilia_cases',
#        'sardegna_cases'],
#       dtype='object')

# %%
data.tail()
# Out:
#     Unnamed: 0 age_classes  male_cases  male_deaths  female_cases  \
# 6            6       60-69       11761         1144          6254
# 7            7       70-79       12281         3146          6868
# 8            8       80-89        8553         3259          7644
# 9            9         >90        1374          558          2973
# 10          10      Uknown          84            1            81
#
#     female_deaths  total_cases  total_deaths  piemonte_cases  lombardia_cases  \
# 6             299        18089          1448            1436             8266
# 7            1041        19238          4196            1551             9651
# 8            1767        16252          5029            1345             7631
# 9             692         4356          1251             289             1553
# 10              1          168             2               3               21
#
#     ...  toscana_cases  umbria_cases  marche_cases  lazio_cases  \
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0    male_cases  male_deaths  female_cases  female_deaths  \
# count   11.000000     11.000000    11.000000     11.000000      11.000000
# mean     5.000000   5269.272727   781.090909   4348.454545     358.000000
# std      3.316625   4913.290244  1248.060692   3352.629218     580.975559
# min      0.000000     84.000000     0.000000     81.000000       0.000000
# 25%      2.500000    924.500000     2.500000   1492.500000       1.500000
# 50%      5.000000   3505.000000    81.000000   3885.000000      29.000000
# 75%      7.500000   9851.000000   851.000000   6999.000000     495.500000
# max     10.000000  12281.000000  3259.000000   9706.000000    1767.000000
#
#         total_cases  total_deaths  piemonte_cases  lombardia_cases  \
# count     11.000000     11.000000       11.000000        11.000000
# mean    9672.636364   1140.909091      739.363636      4188.272727
# std     8102.846935   1802.303385      662.392070      3838.376638
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                    0
# age_classes                   0
# male_cases                    0
# male_deaths                   0
# female_cases                  0
# female_deaths                 0
# total_cases                   0
# total_deaths                  0
# piemonte_cases                0
# lombardia_cases               0
# veneto_cases                  0
# emilia-romagna_cases          0
# valleaosta_cases              0
# trento_cases                  0
# friuli-veneziagiulia_cases    0
# liguria_cases                 0
# toscana_cases                 0
# umbria_cases                  0
# marche_cases                  0
# lazio_cases                   0
# abruzzo_cases                 0
# molise_cases                  0
# campania_cases                0
# puglia_cases                  0
# sicilia_cases                 0
# sardegna_cases                0
# dtype: int64

# %% [markdown]
# # RELATING THE VARIABLES.

# %%
sns.relplot(x='female_cases',y='female_deaths',data=data)

# %%
sns.relplot(x='total_cases',y='total_deaths',data=data)

# %%
sns.relplot(x='male_cases',y='male_deaths',data=data)

# %%
sns.barplot(x='total_cases',y='total_deaths',data=data)
# Out:
# <AxesSubplot:xlabel='total_cases', ylabel='total_deaths'>

# %%
sns.lineplot(x='age_classes',y='total_deaths',data=data)
# Out:
# <AxesSubplot:xlabel='age_classes', ylabel='total_deaths'>

# %%
sns.lineplot(x='age_classes',y='male_deaths',data=data)
# Out:
# <AxesSubplot:xlabel='age_classes', ylabel='male_deaths'>

# %%
sns.lineplot(x='age_classes',y='female_deaths',data=data)
# Out:
# <AxesSubplot:xlabel='age_classes', ylabel='female_deaths'>

# %%
sns.pairplot(data)
